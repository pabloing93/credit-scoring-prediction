# %%
import pandas

# %%
scores = pandas.read_csv('scores.csv', sep=';')
scores
# Out:
#                       model  accuracy  precision    recall  f1_score  \
# 0  Naive_Bayes(Bernulli_NB)  0.707143   0.681223  0.757282  0.717241
# 1    DecisionTreeClassifier  0.702381   0.701493  0.684466  0.692875
# 2      KNeighborsClassifier  0.761905   0.747664  0.776699  0.761905
# 3        LogisticRegression  0.754762   0.737327  0.776699  0.756501
# 4    RandomForestClassifier  0.819048   0.815534  0.815534  0.815534
#
#    roc_auc_score  specificity
# 0       0.708080     0.658879
# 1       0.702046     0.719626
# 2       0.762181     0.747664
# 3       0.755172     0.733645
# 4       0.818982     0.822430

# %%
import matplotlib.pyplot as plt

# %%
colors = ['#0077b6', '#CDDBF3','#9370DB', '#DDA0DD', '#0abeb5']
results_df = scores.set_index('model')
results_df = results_df.T
plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
for metric in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for bar in metric:
    #Bar es una barra del bloque
    labels.append(f'{bar.get_height():.2f}')
  plot.bar_label(metric, labels=labels, label_type='center', rotation=60)
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.legend(title='Modelos')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_33620\577595791.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_33620\577595791.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)

# %%
results_df
# Out:
# model          Naive_Bayes(Bernulli_NB)  DecisionTreeClassifier  \
# accuracy                       0.707143                0.702381
# precision                      0.681223                0.701493
# recall                         0.757282                0.684466
# f1_score                       0.717241                0.692875
# roc_auc_score                  0.708080                0.702046
# specificity                    0.658879                0.719626
#
# model          KNeighborsClassifier  LogisticRegression  \
# accuracy                   0.761905            0.754762
# precision                  0.747664            0.737327
# recall                     0.776699            0.776699
# f1_score                   0.761905            0.756501
# roc_auc_score              0.762181            0.755172
# specificity                0.747664            0.733645
#
# model          RandomForestClassifier
# accuracy                     0.819048
# precision                    0.815534
# recall                       0.815534
# f1_score                     0.815534
# roc_auc_score                0.818982
# specificity                  0.822430

# %% [markdown]
# **Accuracy (exactitud)**: (TP + TN) / TOTAL <br>
# **Specificity**: TN / (TN + FP) <br>
# **Roc_auc_score**: área bajo la curva. El modelo que mayor área abarque, mejor se ajusta a las predicciones. <br>
# ~~**Precision**: (TP) / (TP + FP)~~ [X] <br>
# ~~**Recall**: (TP) / (TP + FN)~~ [X] <br>
# ~~**F1_score**: Utiliza la precisión y el recall [X]~~ <br>

# %%
results_df = results_df.loc[['accuracy', 'specificity', 'roc_auc_score']]
plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
for metric in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for bar in metric:
    #Bar es una barra del bloque
    labels.append(f'{bar.get_height():.2f}')
  plot.bar_label(metric, labels=labels, label_type='center', rotation=0)
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.ylim(0,1.1)
plt.legend(title='Modelos', loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_33620\3430706967.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_33620\3430706967.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
