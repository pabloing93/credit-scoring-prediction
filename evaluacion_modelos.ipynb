# %%
import pandas

# %%
scores = pandas.read_csv('scores.csv', sep=';')
scores
# Out:
#                     model  accuracy  precision    recall  f1_score  \
# 0    KNeighborsClassifier  0.785714   0.763636  0.815534  0.788732
# 1  DecisionTreeClassifier  0.726190   0.715640  0.733010  0.724221
# 2  RandomForestClassifier  0.802381   0.783410  0.825243  0.803783
#
#    roc_auc_score
# 0       0.786272
# 1       0.726318
# 2       0.802808

# %%
import matplotlib.pyplot as plt

# %%
colors = ['#0077b6', '#CDDBF3','#9370DB', '#DDA0DD']
results_df = scores.set_index('model')
results_df = results_df.T
plot = results_df.plot(kind='bar', figsize=(12, 6), colormap='viridis', rot=0, color=colors)
for container in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for value in container:
    #Value es una barra del bloque
    labels.append(f'{value.get_height():.2f}')
  plot.bar_label(container, labels=labels, label_type='center')
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.legend(title='Modelos')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_16664\4060284114.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(12, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_16664\4060284114.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(12, 6), colormap='viridis', rot=0, color=colors)

# %%
results_df
# Out:
# model          KNeighborsClassifier  DecisionTreeClassifier  \
# accuracy                   0.785714                0.726190
# precision                  0.763636                0.715640
# recall                     0.815534                0.733010
# f1_score                   0.788732                0.724221
# roc_auc_score              0.786272                0.726318
#
# model          RandomForestClassifier
# accuracy                     0.802381
# precision                    0.783410
# recall                       0.825243
# f1_score                     0.803783
# roc_auc_score                0.802808
