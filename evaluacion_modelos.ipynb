# %%
import pandas

# %%
scores = pandas.read_csv('scores.csv', sep=';')
scores
# Out:
#                                 model  accuracy  precision    recall  \
# 0            Naive_Bayes(Bernulli_NB)  0.707143   0.681223  0.757282
# 1              DecisionTreeClassifier  0.702381   0.701493  0.684466
# 2                KNeighborsClassifier  0.764286   0.748837  0.781553
# 3                  LogisticRegression  0.754762   0.737327  0.776699
# 4              RandomForestClassifier  0.819048   0.815534  0.815534
# 5      KNeighborsClassifier_optimized  0.773810   0.740260  0.830097
# 6  Naive_Bayes(Bernulli_NB)_optimized  0.704762   0.679825  0.752427
#
#    f1_score  roc_auc_score  specificity
# 0  0.717241       0.708080     0.658879
# 1  0.692875       0.702046     0.719626
# 2  0.764846       0.764608     0.747664
# 3  0.756501       0.755172     0.733645
# 4  0.815534       0.818982     0.822430
# 5  0.782609       0.774862     0.719626
# 6  0.714286       0.705653     0.658879

# %%
import matplotlib.pyplot as plt

# %%
colors = ['#0077b6', '#CDDBF3','#9370DB', '#DDA0DD', '#0abeb5', 'red']
results_df = scores.set_index('model')
results_df = results_df.T
plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
for metric in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for bar in metric:
    #Bar es una barra del bloque
    labels.append(f'{bar.get_height():.2f}')
  plot.bar_label(metric, labels=labels, label_type='center', rotation=60)
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.ylim(0,1.3)
plt.legend(title='Modelos', loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_37288\4145909909.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_37288\4145909909.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)

# %%
results_df
# Out:
# model          Naive_Bayes(Bernulli_NB)  DecisionTreeClassifier  \
# accuracy                       0.707143                0.702381
# precision                      0.681223                0.701493
# recall                         0.757282                0.684466
# f1_score                       0.717241                0.692875
# roc_auc_score                  0.708080                0.702046
# specificity                    0.658879                0.719626
#
# model          KNeighborsClassifier  LogisticRegression  \
# accuracy                   0.764286            0.754762
# precision                  0.748837            0.737327
# recall                     0.781553            0.776699
# f1_score                   0.764846            0.756501
# roc_auc_score              0.764608            0.755172
# specificity                0.747664            0.733645
#
# model          RandomForestClassifier  KNeighborsClassifier_optimized  \
# accuracy                     0.819048                        0.773810
# precision                    0.815534                        0.740260
# recall                       0.815534                        0.830097
# f1_score                     0.815534                        0.782609
# roc_auc_score                0.818982                        0.774862
# specificity                  0.822430                        0.719626
#
# model          Naive_Bayes(Bernulli_NB)_optimized
# accuracy                                 0.704762
# precision                                0.679825
# recall                                   0.752427
# f1_score                                 0.714286
# roc_auc_score                            0.705653
# specificity                              0.658879

# %% [markdown]
# **Accuracy (exactitud)**: (TP + TN) / TOTAL <br>
# **Specificity**: TN / (TN + FP) <br>
# **Roc_auc_score**: área bajo la curva. El modelo que mayor área abarque, mejor se ajusta a las predicciones. <br>
# ~~**Precision**: (TP) / (TP + FP)~~ [X] <br>
# ~~**Recall**: (TP) / (TP + FN)~~ [X] <br>
# ~~**F1_score**: Utiliza la precisión y el recall [X]~~ <br>

# %%
results_df = results_df.loc[['accuracy', 'specificity', 'roc_auc_score']]
plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
for metric in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for bar in metric:
    #Bar es una barra del bloque
    labels.append(f'{bar.get_height():.2f}')
  plot.bar_label(metric, labels=labels, label_type='center', rotation=0)
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.ylim(0,1.1)
plt.legend(title='Modelos', loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_37288\3430706967.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\eddwi\AppData\Local\Temp\ipykernel_37288\3430706967.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
