# %%
import pandas

# %%
scores = pandas.read_csv('scores.csv', sep=';')
scores
# Out:
#                                 model  accuracy  precision    recall  \
# 0              DecisionTreeClassifier  0.702381   0.701493  0.684466
# 1                KNeighborsClassifier  0.761905   0.740909  0.791262
# 2                  LogisticRegression  0.754762   0.737327  0.776699
# 3            Naive_Bayes(Bernulli_NB)  0.707143   0.681223  0.757282
# 4  Naive_Bayes(Bernulli_NB)_optimized  0.704762   0.679825  0.752427
# 5              RandomForestClassifier  0.800000   0.793269  0.800971
#
#    f1_score  roc_auc_score  specificity
# 0  0.692875       0.702046     0.719626
# 1  0.765258       0.762453     0.733645
# 2  0.756501       0.755172     0.733645
# 3  0.717241       0.708080     0.658879
# 4  0.714286       0.705653     0.658879
# 5  0.797101       0.800018     0.799065

# %%
import matplotlib.pyplot as plt

# %%
colors = ['#0077b6', '#CDDBF3','#9370DB', '#DDA0DD', '#0abeb5', 'red']
results_df = scores.set_index('model')
results_df = results_df.T
plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
for metric in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for bar in metric:
    #Bar es una barra del bloque
    labels.append(f'{bar.get_height():.2f}')
  plot.bar_label(metric, labels=labels, label_type='center', rotation=60)
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.ylim(0,1.3)
plt.legend(title='Modelos', loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_3908\4145909909.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_3908\4145909909.py:4: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)

# %%
results_df
# Out:
# model          DecisionTreeClassifier  KNeighborsClassifier  \
# accuracy                     0.702381              0.761905
# precision                    0.701493              0.740909
# recall                       0.684466              0.791262
# f1_score                     0.692875              0.765258
# roc_auc_score                0.702046              0.762453
# specificity                  0.719626              0.733645
#
# model          LogisticRegression  Naive_Bayes(Bernulli_NB)  \
# accuracy                 0.754762                  0.707143
# precision                0.737327                  0.681223
# recall                   0.776699                  0.757282
# f1_score                 0.756501                  0.717241
# roc_auc_score            0.755172                  0.708080
# specificity              0.733645                  0.658879
#
# model          Naive_Bayes(Bernulli_NB)_optimized  RandomForestClassifier
# accuracy                                 0.704762                0.800000
# precision                                0.679825                0.793269
# recall                                   0.752427                0.800971
# f1_score                                 0.714286                0.797101
# roc_auc_score                            0.705653                0.800018
# specificity                              0.658879                0.799065

# %% [markdown]
# **Accuracy (exactitud)**: (TP + TN) / TOTAL <br>
# **Specificity**: TN / (TN + FP) <br>
# **Roc_auc_score**: área bajo la curva. El modelo que mayor área abarque, mejor se ajusta a las predicciones. <br>
# ~~**Precision**: (TP) / (TP + FP)~~ [X] <br>
# ~~**Recall**: (TP) / (TP + FN)~~ [X] <br>
# ~~**F1_score**: Utiliza la precisión y el recall [X]~~ <br>

# %%
results_df = results_df.loc[['accuracy', 'specificity', 'roc_auc_score']]
plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
for metric in plot.containers:
  #Container contiene un bloque de barras que representa a 1 solo modelo de N modelos
  labels = []
  for bar in metric:
    #Bar es una barra del bloque
    labels.append(f'{bar.get_height():.2f}')
  plot.bar_label(metric, labels=labels, label_type='center', rotation=0)
plt.title('Comparación de Métricas por Modelo')
plt.xlabel('Métricas')
plt.ylabel('Puntuación')
plt.ylim(0,1.3)
plt.axhline(y=0.8, color='black', linestyle='--', linewidth=0.7)
plt.legend(title='Modelos', loc='upper left')
plt.tight_layout()

plt.show()
# Out:
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_3908\1496104927.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_3908\1496104927.py:2: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   plot = results_df.plot(kind='bar', figsize=(15, 6), colormap='viridis', rot=0, color=colors)
